# %%
from IPython.core.display import display, HTML, Image
display(HTML("<style>.container { width:99% !important; }</style>"))
Image('https://www.python.org/images/python-logo.gif')
# Out:
# <style>.container { width:99% !important; }</style>

# %% [markdown]
# # Agenda

# %% [markdown]
# - Python Objects
# - The identity of an object - **id()** function
# - Mutable vs Immutable objects in Python

# %% [markdown]
# ###  Objects in Python & how they are created?

# %% [markdown]
# - Everything in Python is an object and every variable holds an object instance.

# %%
12
# Out:
# 12

# %%
"Learning"
# Out:
# 'Learning'

# %%
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
x = 12

y = 12

z = [1, 2, 3, 4]

y = 24

# %% [markdown]
# - When an object is initiated, it is assigned a unique object id. Its type is defined at runtime.
#
#
# - The built-in function **id()** returns the unique id of an object as an integer.
#
#
# - The value returned by **id()** corresponds to the object’s location in memory, although this is specific to the Python implementation and the platform being used.
#
#
# - The **is** operator compares the identity of two objects.

# %%
Image('images-functions/x_y.png', width=500)

# %%
id(y)
# Out:
# 4490995552

# %%
id(12)
# Out:
# 4490995168

# %%
id(x)
# Out:
# 4490995168

# %%
id(23)
# Out:
# 4490995520

# %%
x is 12, x is 23
# Out:
# (True, False)

# %% [markdown]
# ## Mutable vs Immutable objects

# %% [markdown]
# - Objects can be either mutable or immutable.
#
#
# - A mutable object can be changed after it is created, and an immutable object can’t.
#
#
# - For a mutable object you can change its content without changing their identity. (id function returns the same value even after updating the content.)

# %% [markdown]
# ### Integers,  Floats, Strings, Bools are Immutable

# %%
id(12)
# Out:
# 4490995168

# %%
x = 12

# %%
id(x)
# Out:
# 4490995168

# %%
x = 23

# %%
id(x)
# Out:
# 4490995520

# %%
x = x + 12

# %%
print(x, id(x))
# Out:
# 35 4490995904

# %%
id(35)
# Out:
# 4490995904

# %%
Image('images-functions/immutable-integers.png', width=700)

# %% [markdown]
# ### Lists are Mutable

# %%
l = [1, 2, 3, 4]

# %%
id(l)
# Out:
# 4570044448

# %%
for element in l:
    print(element, '\t', id(element))
# Out:
# 1 	 4490994816
# 2 	 4490994848
# 3 	 4490994880
# 4 	 4490994912

# %%
l[0] = -12

# %%
print(l)
# Out:
# [-12, 2, 3, 4]

# %%
id(l)
# Out:
# 4570044448

# %%
for element in l:
    print(element, '\t',id(element))
# Out:
# -12 	 4572935056
# 2 	 4490994848
# 3 	 4490994880
# 4 	 4490994912

# %% [markdown]
# ### Strings are immutable

# %%
sample_string = 'Data Science and Machine Learning'

# %%
id(sample_string)
# Out:
# 4573422480

# %%
sample_string[3] = 'A'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-e784f2b9afae> in <module>
# ----> 1 sample_string[3] = 'A'
#
# TypeError: 'str' object does not support item assignment

# %%
sample_string = "New String"

# %%
id(sample_string)
# Out:
# 4571475120

# %% [markdown]
# ### Tuples are Immutable

# %%
tuple_ = ("ML", "DS")

# %%
print(tuple_[0], tuple_[1])
# Out:
# ML DS

# %%
tuple_[0] = "DL"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-382951a81527> in <module>
# ----> 1 tuple_[0] = "DL"
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(id(tuple_))
# Out:
# 4584623072

# %%
tuple_ = ("DL", tuple_[1])

# %%
tuple_
# Out:
# ('DL', 'DS')

# %%
print(id(tuple_))
# Out:
# 4584560992

# %%
tuple_
# Out:
# ('DL', 'DS')

# %% [markdown]
# ### Special case - partial immutability

# %% [raw]
# If the tuple has an immutable field like a string for example, then it cannot be modified. A mutable field like a list however, can be edited, even if it’s embedded in the “immutable” tuple.

# %%
tuple_1 = ('DL', [1, 2, 3, 4])

# %%
id(tuple_1)
# Out:
# 4584174368

# %%
tuple_1[1][2] = 23

# %%
tuple_1
# Out:
# ('DL', [1, 2, 23, 4])

# %%
id(tuple_1)
# Out:
# 4584174368

# %%
x = "DS"

# %%
id(x)
# Out:
# 4569347824

# %%
x = x + " ML"

# %%
x
# Out:
# 'DS ML'

# %%
id(x)
# Out:
# 4573624496

# %% [markdown]
# ### Caution for Strings
#
# - If you want to write most efficient code, you should be the knowing difference between mutable and immutable in python.
#
#
# - Concatenating string in loops wastes lots of memory , because strings are immutable, concatenating two strings together actually creates a third string which is the combination of the previous two. If you are iterating a lot and building a large string, you will waste a lot of memory creating and throwing away objects.
#
#
# - Python handles mutable and immutable objects differently. Immutable are quicker to access than mutable objects. Also, immutable objects are fundamentally expensive to "change", because doing so involves creating a copy. Changing mutable objects is cheap.

# %%
Image('images-functions/mutable-immutable.png', width=700)
